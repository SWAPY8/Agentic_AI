# %% [markdown]
# File Handling

# %%
file = open(r"C:\Users\Admin\Desktop\SQL\SQL1-5.txt", "r")

content = file.read()
print(content)

# %%
with open("temp.txt", "w", encoding="utf-8") as file1:
    file1.writelines("hello world\nhappy diwali\n")

# %% [markdown]
# CSV FILE HANDLING

# %%
import csv
with open("temp.csv", "w", encoding= "utf-8", newline = "") as file:
    writer = csv.writer(file)
    writer.writerow(["Names", "Age", "Branch", "Contact"])
    writer.writerow(["Swapnil", 22, "AI", 9894856468])
    writer.writerow(["OMKAR", 32, "AI", 8080085353])
    writer.writerows([
        ["hfhd", 22, "AI", 9884789],
        ["Swahfdfbpnil", 22, "AI", 4366832443],
        ["vchgw", 22, "AI", 98989089489]
    ])

# %% [markdown]
# Writing Dictionary Data

# %%
import csv
from pathlib import Path

csv_path = Path(r"C:\Users\Admin\Desktop\Agentic_AI") / "student_data.csv" # here we can define path using "Path" 
student_data = [
    {"name": "swapnil", "id": 101, "branch":"aids"},
    {"name": "sarthak", "id": 102, "branch":"entc"},
    {"name": "omakr", "id": 103, "branch":"aids"}

]
header = ["name", "id", "branch"]
with open(csv_path, "w", encoding= "utf-8", newline = "") as file:
    writer = csv.DictWriter(file, fieldnames = header )
    
    writer.writeheader()
    writer.writerows(student_data)

# %% [markdown]
# JSON FILES

# %%
# json creation and writing data
import json
data = { "name":"sarthak", "age": 90, "branch" : "AI"}
with open("students.json", "w", encoding="utf-8") as json_files:
    x = json.dump(data, json_files, indent=4)

# %%
# JSON String → Dictionary
import json
with open("students.json","r", encoding="utf-8") as file2:
    json_data = file2.read()
    output = json.loads(json_data)
    
print(output)
# Out:
# {'name': 'sarthak', 'age': 90, 'branch': 'AI'}

# %%
# Create student.json and Read it using json.load()
import json
# data = {
#     "name": "Swapnil",
#     "age": 22,
#     "marks": 95
# }
# with open("Students.json", "w", encoding="utf-8") as file3:
#     x = json.dump(data, file3)

with open("Students.json", "r", encoding="utf-8") as file4:
    
    output= json.load(file4)
    print(output)
# Out:
# {'name': 'Swapnil', 'age': 22, 'marks': 95}
