# %%
#  Personal Profile Program 

student_name = "Gagandip Pathare"
age = 22
college_name = "G.S.MOZE COE"
city = "Pune" 
course_name = "Agentic AI"

print("Name of Student is " + student_name + "." +" Age is " +str(age)+ "." + " College Name is "+ college_name + "." + " Lived in " + city + "." + " Gaining knowledge of " + course_name)
# Out:
# Name of Student is Gagandip Pathare. Age is 22. College Name is G.S.MOZE COE. Lived in Pune. Gaining knowledge of Agentic AI

# %%
# Student Report 
 

student_name = "Tatya Gite"
roll_no = 111
branch_name = "CS"
Percentage = "18 %" 
Passed = False

print( f"He is {student_name}. His roll no is {roll_no}. Studying in {branch_name} branch. last sem he got {Percentage}. so that his passing status is {Passed}." )
# Out:
# He is Tatya Gite. His roll no is 111. Studying in CS. last sem he got 18 %. so that his passing status is False.

# %%
#Identifier Practice 

student_name = "Tatya Gite"
roll_no = 111
branch_name = "CS"
Percentage = "18 %" 
Passing_status = False
age = 22
college_name = "G.S.MOZE COE"
city = "Pune" 
course_name = "Agentic AI"
attendence = "80 %"

print("All details about student xyz : ")
print(f" Name = {student_name }, Roll No. = {roll_no}, Branch Name = {branch_name}, Percentage = {Percentage}, Pssing Status = {Passing_status}, Age = {age}, College Name = {college_name}, City = {city}, Course Name = {course_name}, Attendence = {attendence} ")
# Out:
# All details about student xyz :
#  Name = Tatya Gite, Roll No. = 111, Branch Name = CS, Percentage = 18 %, Pssing Status = False, Age = 22, College Name = G.S.MOZE COE, City = Pune, Course Name = Agentic AI, Attendence = 80 %

# %%
# Comments Practice
# personal background
print("My name is Swapnil Gandhale. " \
"I come from farmer family" \
"I love to play cricket.")

# professional details
print("I completed Bachelors in AI&DS from G.S.Moze Balewadi" \
"I have completed remote internship at neuai labs as a data analyst" \
"Along with completed one project on Uber Ride Analysis ")

""" 
above details are original and wont change in any circumstances
"""
# Out:
# My name is Swapnil Gandhale. I come from farmer familyI love to play cricket.
# I completed Bachelors in AI&DS from G.S.Moze BalewadiI have completed remote internship at neuai labs as a data analystAlong with completed one project on Uber Ride Analysis
# ' \nabove details are original and wont change in any circumstances\n'

# %%
_2student = " 111 "
student1_name = "sarthak"
student2_name = "tatya"
branch_name = "AI&DS"
Percentage_for_passing = 79
employee_id = 898 

print(_2student)
print(student1_name)
print(student2_name)
print(branch_name)
print(Percentage_for_passing)
print(employee_id)
# Out:
#  111
# sarthak
# tatya
# AI&DS
# 79
# 898
