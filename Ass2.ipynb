# %%
age1 = "78"
age2 = 67
print(int(age1) + age2)
# Out:
# 145

# %%
age1 = "89"
age2 = "89.72"

temp = float(age2)

add = int(age1) + int(temp)
print(add)
print(type(age2))
print(id(add))
# Out:
# 178
# <class 'str'>
# 140732881754776

# %% [markdown]
# Operator

# %%
num1 = 87
num2 = 98
res = num1 + num2
res1 = res
res2 = res1
res1 += res
res2 -= res
print(res1)


num3 = 98
num4 = 33
num5 = 54
result = num3 < num4 and num5 < num3
print( not(result) )

# data saved based onn the values not based on variable name
name1 = "rahul"
name2 = "rahul"
name3 = "rahul"

num1 = 12
num2 = 12

print(id(num1))
print(id(num2))

print(name1 is name2)
# Out:
# 370
# True
# 140732930639320
# 140732930639320
# True
